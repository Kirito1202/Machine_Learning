# %% [markdown]
# # Common pitfalls in the interpretation of coefficients of linear models

# %% [markdown]
# 在线性模型中，目标值被建模成特征的线性组合。多元线性模型的系数刻画了某一特征$X_i$与目标变量$y$之间的关联关系，该结论成立的前提是**其余所有特征保持不变**（条件相关性）。这和单独绘制$y$与$X_i$并拟合一条直线有本质区别：后者在拟合过程中纳入了其余特征全部取值带来的影响，属于边缘相关性。
#
# 本示例将为线性模型系数的解读提供思路，同时指出两类典型问题：一是线性模型本身不适用于描述当前数据集；二是特征之间存在相关性。
